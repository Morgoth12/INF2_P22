# %% [markdown]
# # INF2 TP3

# %% [markdown]
# # Chazelas Clément, Mantion Nathan

# %% [markdown]
# # Exercice 1

# %%
import googlemaps #On importe le module pour la classe Gmap
 
class Gmap: #définition de la classe
    def coordgps(adresse):
        gmaps = googlemaps.Client(key='AIzaSyBTeRxf61DWGHagCM2SOVupUhdo2POEkxE') #Connexion à l'API de GoogleMaps avec le token fourni par le sujet
        geocode_result = gmaps.geocode(adresse) #Recherche de la localisation à partir de l'adresse
        lat = geocode_result[0]["geometry"]["location"]["lat"] #Calcul de la latitude
        lng = geocode_result[0]["geometry"]["location"]["lng"] #Calcul de la longitude
        return lat,lng #Renvoi des coordonnées
 
class Lieu: #Définition de la classe
    def __init__(self,name,adress): #Constructeur de la classe
        self.nom = name #Définition de l'attribut nom à partir des valeurs entrées dans le code par l'utilisateur
        self.adresse = adress #Définition de l'attribut adresse à partir des valeurs entrées dans le code par l'utilisateur
        self.latitude , self.longitude = Gmap.coordgps(adress) #Définition des coordonnées GPS à partir de la fonction de la classe Gmap et de l'adresse entrée
 
    def __str__(self):
        return f"{self.nom} : {self.adresse} ({self.latitude} , {self.longitude})" #Méthode qui renvoie l'objet sous forme de chaîne de caractères
   
    def detail(self): #Méthode affichant l'objet sous sa forme str
        print(self)

# %% [markdown]
# Premièrement nous avons copié la classe Gmap dans notre programme pour l’utiliser dans notre classe Lieu. Une fois cela effectué nous avons créé le constructeur de notre classe. Puisque nous avons la méthode coordgps, nous n’avons besoin que du nom et de l’adresse de notre lieu pour définir l’objet, puis nous utilisons le tuple retourné par la méthode coordgps pour définir nos deux attributs latitude et longitude.
# Pour afficher les attributs, on définit premièrement une fonction __str__ qui retournera notre objet de classe Lieu en un objet de classe str puis nous définissons une fonction qui ne fait qu’imprimer l’objet.

# %% [markdown]
# # Exercice 2

# %%
class Personne:
    def __init__(self,nom="Doe",prenom="John",age=30,sexe="H"): #Constructeur de la classe
        self.nom = nom #Définition de l'attribut nom à partir des valeurs entrées dans le code par l'utilisateur
        self.prenom = prenom #Définition de l'attribut prenom à partir des valeurs entrées dans le code par l'utilisateur
        if type(age) == int: #Vérification de l'âge pour qu'il soit bien un entier
            self.age = age #Définition de l'âge
        else:
            raise TypeError("Personne.age : age value must be int type") #Erreur dans le cas où la valeur entrée par l'utilisateur n'est pas un entier
        if sexe == "H" or sexe == "F": #Vérification de la concordance des données pour que les valeurs ne soient que des "H" ou "F"
            self.sexe = sexe #Définition du sexe
        else:
            raise ValueError("Personne.sexe : this attribute only can be 'H' or 'F' values") #Erreur si les données entrées pour l'attribut sexe ne sont par "H" ou "F"
 
    def __str__(self):
        return f"Prenom : {self.prenom} , Nom : {self.nom} , Age : {self.age} ans , Sexe : {self.sexe}" #Méthode qui renvoie l'objet sous forme de chaîne de caractères
 
    def getName(self):
        return self.nom #Méthode pour renvoyer le nom
 
    def getSurname(self):
        return self.prenom #Méthode pour renvoyer le prenom
 
    def getAge(self):
        return self.age #Méthode pour renvoyer l'âge
   
    def getSex(self):
        return self.sexe #Méthode pour renvoyer le sexe
   
    def sameLastName(self,other): #Définition de la méthode sameLastName pour savoir si deux Personnes ont le même nom de famille
        if type(other) == Personne: #Vérification du type de la variable entrée dans la méthode pour s'assurer qu'elle est de type Personne
            return self.nom == other.nom #Renvoi d'un booléen
        raise TypeError("sameLastName(p) : p must be a Personne object") #Erreur si la variable entrée n'est pas de type Personne
 
    def oldest(self,other): #Définition la fonction oldest qui renvoie la personne la plus vieille entre deux Personnes
        if type(other) == Personne : #Vérification du type de la variable entrée dans la méthode pour s'assurer qu'elle est de type Personne
            if self.age < other.age: #Si la Personne entrée est plus vieille elle est renvoyée par la méthode
                return other
            return self #Si la Personne avec laquelle on appelle la fonction est plus vieille ou a le même âge, elle est renvoyée
        raise TypeError("oldest(p) : p must be a Personne object") #Erreur si la variable entrée n'est pas de type Personne
        

def __main__() :   
    a = Personne() #Définition d'un objet Personne qui est l'objet par défaut
    b = Personne("Sébastien","Patrick",68,"H") #Définition d'un objet personne
    c = Personne("Doe","Mirelle",43,"F") #Définition d'un objet personne

    print(a.getName()) #Test de la méthode getter pour l'attribut nom
    print(b.getSurname()) #Test de la méthode getter pour l'attribut prenom
    print(c.getAge()) #Test de la méthode getter pour l'attribut age
    print(c.getSex()) #Test de la méthode getter pour l'attribut sexe
    print(a.sameLastName(b)) #Test du premier cas possible dans la méthode sameLastName (si deux personnes n'ont pas le même nom de famille)
    print(a.sameLastName(c)) #Test du deuxième cas possible dans la méthode sameLastName (si deux personnes ont effectivement le même nom de famille)
    print(b.oldest(c)) #Test du premier cas possible dans la méthode oldest (si la personne entrée est plus jeune)
    print(c.oldest(a)) #Test du deuxième cas possible dans la méthode oldest (si la personne entrée est plus vieille)
    
if __name__ == '__main__' :
    main()

# %% [markdown]
# Pour définir notre constructeur nous utilisons une définition classique. Dans la déclaration des variables utilisées dans la fonction __init__ on ajoute la valeur par défaut après les attributs comme il suit attribut=valeurParDefaut nous introduisons donc nos valeurs par défaut à savoir celles de John Doe. N’ayant vu aucune mention d’attributs cachés dans la définiton des attributs, nous ne passons pas nos attributs en attributs cachés. Pour les attributs age et sexe nous choisissons de rajouter une condition afin d’ajouter de la cohérence dans les données. Pour l’attribut age on s’assure du fait que la valeur entrée est bien de type int. Pour l’attribut sexe on choisit de limiter les possibilités aux valeurs “H” et “F”. En cas de non respect de ses conditions, on renvoie une erreur
# Pour définir nos getters, on crée une fonction par attribut qui retourne automatiquement l’attribut demandé.
# On ajoute aussi une fonction __str__ au cas où l’utilisateur voudrait afficher l’objet.
# Pour la méthode sameLastName puisqu’il semble que la méthode doit donner une réponse positive ou négative à la question “p1 a-t-il le même nom de famille que p2 ?”. La logique a été de retourner un booléen défini par une condition. Puisque notre condition demande les attributs nom des deux objets, il est indispensable qu’ils soient des objets de type Personne, on ajoute donc une condition préalable et retourne une erreur si l’objet entré dans la méthode n’est pas un objet Personne.
# Pour la méthode older nous partons de la même base de vérification de la classe des objets pour éviter tout problèmes. Puis on ajoute une comparaison d’âge, si l’objet entré est plus vieux, c’est lui qui est retourné et inversement. Il reste un cas où il faut apporter une réponse : Celui où les deux Personne on le même attribut age nous avons choisi de retourner l’objet avec lequel on appelle la fonction toutefois il est aussi possible de retourner l’objet entré dans la méthode. Ou bien on peut ajouter une condition qui, en cas d’égalité, renvoie un tuple ou une liste contenant les deux objets.

# %% [markdown]
# # Exercice 3

# %%
from math import * #On importe toute les fonctions du module math afin de pouvoir utiliser la fonction sqrt plus tard

class Point : #On définit la classe Point
    def __init__(self, abs, ord) : #On définit le constructeur de la classe Point avec ses attributs
        self.abs = abs
        self.ord = ord
    
    @property #On définit le getter de l'atribut abs
    def abs(self) :
        return self.__abs

    @abs.setter #On definit le setter de l'atribut abs
    def abs(self, abs) :
        if not isinstance(abs, float) : #On verifie que abs est bien un flottant
            raise TypeError("L'abscisse n'est pas un float")
        self.__abs = abs 

    @property #On définit le getter de l'atribut ord
    def ord(self) :
        return self.__ord

    @ord.setter #On definit le setter de l'atribut
    def ord(self, ord) :
        if not isinstance(ord, float) : #On verifie que ord est bien un flottant
            raise TypeError("Les ordonnées ne sont pas un float")
        self.__ord = ord 
    
    def __calculerDistance__(self, p) : 
        if not isinstance(p, Point) : #On verifie que p est bien un Point
            raise TypeError("P n'est pas un Point")
        return sqrt((p.abs - self.abs)**2+(p.ord - self.ord)**2)

    def __calculerMillieu__(self, p) :
        if not isinstance(p, Point) : #On verifie que p est bien un Point
            raise TypeError("P n'est pas un Point")
        return Point((1/2)*(p.abs + self.abs), (1/2)*(p.ord + self.ord))



class TroisPoints : #On définie la classe TroisPoints
    def __init__(self, premier, deuxième, troisième) : #On définit le constructeur de la classe TroisPoints avec ses attributs
        self.premier = premier
        self.deuxième = deuxième
        self.troisième = troisième
    
    @property #On définit le getter de l'atribut premier
    def premier(self) :
        return self.__premier

    @premier.setter #On definit le setter de l'atribut premier
    def premier(self, premier) :
        if not isinstance(premier, Point) : #On verifie que premier est bien un Point
            raise TypeError("Premier n'est pas un Point")
        self.__premier = premier 

    @property #On définit le getter de l'atribut deuxième
    def deuxième(self) :
        return self.__deuxième

    @deuxième.setter #On definit le setter de l'atribut deuxième
    def deuxième(self, deuxième) :
        if not isinstance(deuxième, Point) : #On verifie que deuxième est bien un Point
            raise TypeError("Deuxième n'est pas un Point")
        self.__deuxième = deuxième 

    @property #On définit le getter de l'atribut troisième
    def troisième(self) :
        return self.__troisième

    @troisième.setter #On definit le setter de l'atribut deuxième
    def troisième(self, troisième) :
        if not isinstance(troisième, Point) : #On verifie que troisième est bien un Point
            raise TypeError("P n'est pas un Point")
        self.__troisième = troisième 

    def __sontAlignes__(self, premier, deuxième, troisième) :
        alignés = False #On crée une variable booléenne et on lui affecte la valeur False
        if (Point.__calculerDistance__(self.premier, self.deuxième) == Point.__calculerDistance__(self.premier, self.troisième) + Point.__calculerDistance__(self.deuxième, self.troisième) or Point.__calculerDistance__(self.premier, self.troisième) == Point.__calculerDistance__(self.premier, self.deuxième) + Point.__calculerDistance__(self.deuxième, self.troisième)) or Point.__calculerDistance__(self.deuxième, self.troisième) == Point.__calculerDistance__(self.premier, self.troisième) + Point.__calculerDistance__(self.premier, self.deuxième) : #On applique le raisonnement nous permettant de déterminer si 3 points sont alignés ou non en calculant leur longueur à l'aide de la méthode __calculerDistance__
            alignés = True #Si les 3 points sont alignés notre variable booléenne prend la valeur True
        return alignés 
    
    def __estIsocèle__(self, premier, deuxième, troisième) :
        isocèle = False #On crée une variable booléenne et on lui affecte la valeur False
        if (Point.__calculerDistance__(self.premier, self.deuxième) == Point.__calculerDistance__(self.premier, self.troisième) or Point.__calculerDistance__(self.premier, self.deuxième) == Point.__calculerDistance__(self.deuxième, self.troisième)) or Point.__calculerDistance__(self.deuxième, self.troisième) == Point.__calculerDistance__(self.premier, self.troisième) : #On applique le raisonnement nous permettant de déterminer si un triangle est isocèle ou non en calculant la longueur de ses côtés à l'aide de la méthode __calculerDistance__
            isocèle = True #Si le triangle est isocèle notre variable booléenne prend la valeur True
        if self.__sontAlignes__(self.premier, self.deuxième, self.troisième) == True : #On fait en sorte que si les points sont alignés mais à equidistance le programme ne dise pas que le triangle est isocèle
            isocèle = False
        return isocèle

    def __str__(self) :
        return f"Les trois points sont alignés : {self.__sontAlignes__(self.premier, self.deuxième, self.troisième)} et le triangle est isocèle : {self.__estIsocèle__(self.premier, self.deuxième, self.troisième)}" #A l'aide de la méthode __str__ on renvois le résultat de nos deux précédentes méthodes


def main() :
    p1 = Point(float(input("Entrez l'abscisse du point 1 :  ")), float(input("Entrez les ordonnées du point 1 :  "))) #On demande à l'utilisateur de rentrer les coordonnées des trois points, qui seront des objets de la classe Point
    p2 = Point(float(input("Entrez l'abscisse du point 2 :  ")), float(input("Entrez les ordonnées du point 2 :  ")))
    p3 = Point(float(input("Entrez l'abscisse du point 3 :  ")), float(input("Entrez les ordonnées du point 3 :  ")))
    print(TroisPoints(p1, p2, p3)) #On affiche si les trois points sont alignés et si le triangle formé par ces derniers est isocèle ou non 

if __name__ == '__main__' :
    main()

# %% [markdown]
# On commence par définir la classe Point avec son constructeur comportant 2 attributs : abs et ord, on définis ensuite leur getter et setter en vérifiant à chaque fois s'il s'agit bien de flottants.
# On va ensuite définir la méthode __calculerDistance__ qui permettra de calculer la distance entre 2 points : self et p, qui sont respectivement l'objet courant et un objé donné en paramètre. On vérifie que p est bien un objet de la classe Point. On va ensuite retourne √ (x2 − x1 )**2 + (y2 − y1 )**2 qui est la formue calculant la distance ntre 2 point, avec (x1, y1) les coordonnées de self et (x2, y2) les coordonnées de p.
# On va ensuite définir la méthode __calculerMillieu__ qui permettra de calculer le point se situant entre les deux points indiqués en paramètres, à savoir self et p. On commence par vérifier que p est bien un objet de la classe Point et on renvoi ensuite Point((x1+x2)/2,(y1+y2)/2) qui correspond au point situé au milieu des points self et p.
# On va maintenant définir la classe TroisPoints, avec son constructeur comportant 3 attributs : premier, deuxième et troisième, on definis ensuite leur getter et setter en vérifiant à chaque fois que ce sont bien des objets de la classe Point.
# On définit ensuite la méthode __sontAlignés__ qui prend en paramètre self, premier, deuxième et troisième. On commence par définir une variable booléenne "alignés" que l'on initialise à à False. On vérifie ensuite si les 3 points sont alignés à l'aide de la formule le peremettant (on s'aide ici de la méthode __calculerDistance__ que l'on a défini avant). Si nos 3 points sont alignés notre variable alignés prend la valeur True. On finis par envoyer la variable "alignés".
# On va ensuite définir la méthode __estIsocèle__ qui a comme paramètres self, premier, deuxième, troisième. On va commencer par initialiser la variable booléenne isocèle à False. On teste ensuite si le triangle est isocèle, à l'aide de la méthode fournit (on s'aide ici de la méthode __calculerDistance__ que l'on a défini avant). Si le triangle est isocèle alors la variable isocèle prend la valeur True. On traite ensuite la cas particulier ou les points sont alignés à une distance telle que la méthode nous dit que le triangle est isocèle. On teste donc si les 3 points sont alignés ou non et s'ils le sont on remet la variable isocèle à False. On finit par renvoyer cette variable.
# Enfin, on définis la méthode __str__ de la classe TroisPoint afin que l'on puisse avoir un affichage de ce que l'on vient de déterminer.
# On cré ensuiter le main dans lequel on demandera à l'utilisateur de saisir les coordonnées de trois points différents et on affiche ensuite si ces trois points sont alignés ou non et s'ils forment un triangle isocèle.
